# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "biorxiv": {
        "file" : "biorxiv.bib",
        "venuekey": "publisher",
        "venue-pretext": "Already on BioRxiv ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;",
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-").replace('&apos;', ',').replace('&amp;', '&').replace('&quot;', '"')

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")).replace('&apos;', ',').replace('&amp;', '&').replace('&quot;', '"') + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            # note = False
            # if "note" in b.keys():
            #     if len(str(b["note"])) > 5:
            #         b["note"] = b["note"].replace(", ", " ")
                                          
            #         md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
            #         note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            # if note:
            #     md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
#  C. Reed,  R. Denise,  J. Hourihan,  J. Babor,  M. Jaroch,  M. Martinelli,  G. Hutinet,  V. Crecy-Lagard, "Beyond blast: enabling microbiologists to better extract literature, taxonomic distributions and gene neighbourhood information for protein families."
# SUCESSFULLY PARSED RN6873: " Beyond blast: enabling microbiologists to better extract lit ... "
#  A. Cortes-Martin,  R. Denise,  E. Guerin,  S. Stockdale,  L. Draper,  R. Ross,  A. Shkoporov,  C. Hill, "Isolation and characterization of a novel lytic Parabacteroides distasonis bacteriophage phiPDS1 from the human gut."
# SUCESSFULLY PARSED RN6874: " Isolation and characterization of a novel lytic Parabacteroi ... "
#  S. Abby,  R. Denise,  E. Rocha, "Identification of Protein Secretion Systems in Bacterial Genomes Using MacSyFinder Version 2."
# SUCESSFULLY PARSED RN6875: " Identification of Protein Secretion Systems in Bacterial Gen ... "
#  Bertrand Néron,  Rémi Denise,  Charles Coluzzi,  Marie Touchon,  Eduardo Rocha,  Sophie Abby, "MacSyFinder v2: Improved modelling and search engine to identify molecular systems in genomes."
# SUCESSFULLY PARSED RN6881: " MacSyFinder v2: Improved modelling and search engine to iden ... "
#  R. Denise,  J. Babor,  J. Gerlt,  V. Crecy-Lagard, "Pyridoxal 5,-phosphate synthesis and salvage in Bacteria and Archaea: predicting pathway variant distributions and holes."
# SUCESSFULLY PARSED RN6876: " Pyridoxal 5'-phosphate synthesis and salvage in Bacteria and ... "
#  J. Chlebek,  R. Denise,  L. Craig,  A. Dalia, "Motor-independent retraction of type IV pili is governed by an inherent property of the pilus filament."
# SUCESSFULLY PARSED RN6877: " Motor-independent retraction of type IV pili is governed by  ... "
#  D. Sheppard,  J. Berry,  R. Denise,  E. Rocha,  S. Matthews,  V. Pelicic, "The major subunit of widespread competence pili exhibits a novel and conserved type IV pilin fold."
# SUCESSFULLY PARSED RN6879: " The major subunit of widespread competence pili exhibits a n ... "
#  R. Denise,  S. Abby,  E. Rocha, "The Evolution of Protein Secretion Systems by Co-option and Tinkering of Cellular Machineries."
# SUCESSFULLY PARSED RN6878: " The Evolution of Protein Secretion Systems by Co-option and  ... "
#  R. Denise,  S. Abby,  E. Rocha, "Diversification of the type IV filament superfamily into machines for adhesion, protein secretion, DNA uptake, and motility."
# SUCESSFULLY PARSED RN6880: " Diversification of the type IV filament superfamily into mac ... "
